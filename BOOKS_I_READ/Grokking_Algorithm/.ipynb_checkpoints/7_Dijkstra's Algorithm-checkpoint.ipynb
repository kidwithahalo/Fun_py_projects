# %% [markdown]
#     While Breadth First is shortest path algorithm, Dijkstra is a fastest route algorithm

# %% [markdown]
# When you work with Dijkstra’s algorithm, each edge in the graph has a number associated with it, hese are called **weights**

# %% [markdown]
#     A graph with weights is called a weighted graph.
#     A graph without weights is called an unweighted graph.

# %% [markdown]
#       To calculate Shortest path , we use
#             Breadth first for unweighted graphs
#             Dijkstra for weighted graphs

# %% [markdown]
# Dijkstra’s algorithm only works with _directed acyclic graphs_, called **DAGs** for short.

# %% [markdown]
# ![Screenshot%202021-12-08%20at%207.21.53%20AM.png](attachment:Screenshot%202021-12-08%20at%207.21.53%20AM.png)

# %% [markdown]
# ![Screenshot%202021-12-08%20at%207.26.47%20AM.png](attachment:Screenshot%202021-12-08%20at%207.26.47%20AM.png)

# %% [markdown]
# #### <font color = 'red'> Once you process a node, it means there’s no cheaper way to get to that node. So negative weights algorithm fail Dijksrtra's algo

# %% [markdown]
# ## Bellman Ford Algorithm
#         is used for negative weight graphs

# %% [markdown]
# ### <font color ='green'> Question

# %% [markdown]
# ![Screenshot%202021-12-08%20at%207.44.12%20AM.png](attachment:Screenshot%202021-12-08%20at%207.44.12%20AM.png)

# %% [markdown]
# ## Implementation

# %%
'''we will have to make three hash tables and update the costs and parent hash tables as we proceed'''

graph = {}
graph['you'] = ['alice','bob','claire']
# these are the people immediate close to you in graph

# representing the weight of those edges
graph['start'] = {}
graph['start']['a'] = 6  #6 minutes from start to node a
graph['start']['b'] = 2  #2 minutes from start to node b

# graph['start'] is now a hash tables and we can get neighbours as:
print(graph['start'].items())
# Out:
# dict_items([('a', 6), ('b', 2)])

# %%
# the graph
graph = {}
graph["start"] = {}
graph["start"]["a"] = 6
graph["start"]["b"] = 2

graph["a"] = {}
graph["a"]["fin"] = 1

graph["b"] = {}
graph["b"]["a"] = 3
graph["b"]["fin"] = 5

# Finish node does not have any neigghbours
graph["fin"] = {}

# the costs table
infinity = float("inf")
costs = {}
costs["a"] = 6
costs["b"] = 2
costs["fin"] = infinity

# the parents table
parents = {}
parents["a"] = "start"
parents["b"] = "start"
parents["fin"] = None

processed = []





# # nodes where we cannot yet identify cost will be marked as infinity
# infinity = float('inf')

# # costs tabels from start to node given
# costs = {}
# costs['a'] = 6
# costs['b'] = 2
# costs['fin'] = infinity

# # another set of hash table for redefined parents
# parents = {}
# parents['a'] = 'start'
# parents['b'] = 'start'
# parents['fin'] = None

# # keeping track of all nodes we already processed so that each node is processed just once
# processed = []

# %%
# finding the lowest cost node
def find_lowest_cost_node(costs):
    lowest_cost = float('inf')
    # setting thr lowest cost to max and then minimising
    lowest_cost_node = None
    # selecetion of node so far
    for node in costs:
        # going through each node
        cost = costs[node] 
        # updating cost of each node 
        if cost < lowest_cost and node not in processed:
            # if it's the lowest cost so far and hasn't been proceseed yet
            lowest_cost = cost
            # set it as the new lowest cost node
            lowest_cost_node = node 
    return lowest_cost_node


node = find_lowest_cost_node(costs)
# finding the lowest cost node that we haven't processed yet
while node is not None:
    # if all nodes are processed, we are done with this while
    cost = costs[node]
    neighbours = graph[node]
    for n in neighbours.keys():
        # go through all neighbours for this node.
        # See if it's cheaper to get to this node
        new_cost = cost + neighbours[n]
        if costs[n] > new_cost:
            # this node now becones new parent for this neighbour 
            parents[n] = node
    processed.append(node)
    # marking the node as processed
    node = find_lowest_cost_node(costs)
    # next node, and same iteration


print("Cost from the start to each node:")
print(costs)
# Out:
# Cost from the start to each node:
# {'a': 6, 'b': 2, 'fin': inf}

# %% [markdown]
# ## Problem Set Now

# %% [markdown]
# ![Screenshot%202021-12-08%20at%206.47.19%20PM.png](attachment:Screenshot%202021-12-08%20at%206.47.19%20PM.png)

# %%
# the graph
graph = {}
graph["start"] = {}
graph["start"]["a"] = 6
graph["start"]["b"] = 2

graph["a"] = {}
graph["a"]["fin"] = 1

graph["b"] = {}
graph["b"]["a"] = 3
graph["b"]["fin"] = 5

graph["fin"] = {}

# the costs table
infinity = float("inf")
costs = {}
costs["a"] = 6
costs["b"] = 2
costs["fin"] = infinity

# the parents table
parents = {}
parents["a"] = "start"
parents["b"] = "start"
parents["fin"] = None

processed = []

def find_lowest_cost_node(costs):
    lowest_cost = float("inf")
    lowest_cost_node = None
    # Go through each node.
    for node in costs:
        cost = costs[node]
        # If it's the lowest cost so far and hasn't been processed yet...
        if cost < lowest_cost and node not in processed:
            # ... set it as the new lowest-cost node.
            lowest_cost = cost
            lowest_cost_node = node
    return lowest_cost_node

# Find the lowest-cost node that you haven't processed yet.
node = find_lowest_cost_node(costs)
# If you've processed all the nodes, this while loop is done.
while node is not None:
    cost = costs[node]
    # Go through all the neighbors of this node.
    neighbors = graph[node]
    for n in neighbors.keys():
        new_cost = cost + neighbors[n]
        # If it's cheaper to get to this neighbor by going through this node...
        if costs[n] > new_cost:
            # ... update the cost for this node.
            costs[n] = new_cost
            # This node becomes the new parent for this neighbor.
            parents[n] = node
    # Mark the node as processed.
    processed.append(node)
    # Find the next node to process, and loop.
    node = find_lowest_cost_node(costs)

print("Cost from the start to each node:")
print(costs)
# Out:
# Cost from the start to each node:
# {'a': 5, 'b': 2, 'fin': 6}
