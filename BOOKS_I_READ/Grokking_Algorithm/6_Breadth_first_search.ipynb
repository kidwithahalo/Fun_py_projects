# %% [markdown]
# ## Abstract data structures : Graphs
#     A graph models a set of connection. Graphs are made of nodes and edges

# %% [markdown]
# ## <font color='red'> Breath First search
#     Finding the shortest something.
#     It answers to us two questions
#     -  Is there a path from node A to node B?
#     -  What is the shortest path from node A to node B?

# %% [markdown]
# ## Queue
#     Queues are similar to stacks. You can’t access random elements in the queue. Instead, there are two only operations,
#     enqueue  - adding element to the queue
#     dequeue  - removing the element from the queue

# %% [markdown]
# Queue is FIF0, while stack is LIFO

# %% [markdown]
# # Implementing the graph

# %%
graph ={}

graph['you'] = ['alice','bob','claire']

# %% [markdown]
#     we have mapped 'you' to the three neighbours

# %%
graph = {}

graph["you"] = ["alice", "bob", "claire"]
graph["bob"] = ["anuj", "peggy"]
graph["alice"] = ["peggy"]
graph["claire"] = ["thom", "jonny"]
graph["anuj"] = []
graph["peggy"] = []
graph["thom"] = []
graph["jonny"] = []

# %%
def person_is_seller(name):
      return name[-1] == 'm'

# %%
# deque at work

deque('claire')
# Out:
# deque(['c', 'l', 'a', 'i', 'r', 'e'])

# %%
from collections import deque

def search(name):
    search_queue = deque()
    search_queue += graph[name]
    # This is how you keep track of which people you've searched before.
    searched = set()
    while search_queue:
        person = search_queue.popleft()
        # Only search this person if you haven't already searched them.
        if person not in searched:
            if person_is_seller(person):
                print(person + " is a mango seller!")
                return True
            else:
                search_queue += graph[person]
                # Marks this person as searched
                searched.add(person)
    return False

search("you")
# Out:
# thom is a mango seller!
# True

# %%
deque('ravi', 3)
# Out:
# deque(['a', 'v', 'i'])

# %% [markdown]
#     Breadth-irst search takes O(number of people + number of edges), and it’s more commonly written as O(V+E)
#     (V for number of vertices, E for number of edges).

# %% [markdown]
# # <font color = 'red'> Tree
#      A tree is a special type of graph, where no edges ever point back.

# %% [markdown]
# ![Screenshot%202021-12-07%20at%202.48.01%20PM.png](attachment:Screenshot%202021-12-07%20at%202.48.01%20PM.png)
