# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
random.seed(0)

matplotlib.rcParams['figure.figsize'] = (17,11)
random.seed(a=42)

# %% [markdown]
# ## $ \text{Our original polynomial is : } - x^2+x+15 $

# %%
# Our original polynomial is -x^2+x+15
coefs = [15,1,-1]

def polynomial(coefs, x):
    n = len(coefs)
    return sum([coefs[i]*x**i for i in range(n)])

def draw_polynomial(coefs):
    n = len(coefs)
    x = np.linspace(-5, 5, 1000)
    plt.ylim(-20,20)
    plt.plot(x, sum([coefs[i]*x**i for i in range(n)]), linestyle='-', color='black')

draw_polynomial(coefs)

# %%
X = []
Y = []
for i in range(40):
    x = random.uniform(-5,5)
    y = polynomial(coefs, x) + random.gauss(0,2)
    X.append(x)
    Y.append(y)

# %%
plt.scatter(X, Y);

# %% [markdown]
# ## Training a polynomial regression

# %%
import turicreate as tc

data = tc.SFrame({
    'x': X,
    'y': Y
})

data
# Out:
# Columns:
# 	x	float
# 	y	float
#
# Rows: 40
#
# Data:
# +---------------------+---------------------+
# |          x          |          y          |
# +---------------------+---------------------+
# | -0.8077508466412748 |  11.435560737659625 |
# |  4.347062577364273  | -0.7707490836030138 |
# |  -2.957408005764636 |  2.9849247138055475 |
# |  -1.042141532087455 |  11.427949969110392 |
# |  1.7169022295997127 |  13.230349830673623 |
# |  2.518644924144021  |  12.833429424592516 |
# |  -4.274568855068427 | -14.496518004055432 |
# |  4.960964478550945  |  -2.785716558377983 |
# | -4.2673927890036705 | -7.1177777541225105 |
# |   4.33259377993709  |  2.0894511298454015 |
# +---------------------+---------------------+
# [40 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# # Adding columns to our dataset corresponding to $x^2, x^3, ..., x^{200}$

# %%
for i in range(2,200):
    string = 'x^' + str(i)
    data[string] = data['x'].apply(lambda x: x**i)
    
data
# Out:
# Columns:
# 	x	float
# 	y	float
# 	x^2	float
# 	x^3	float
# 	x^4	float
# 	x^5	float
# 	x^6	float
# 	x^7	float
# 	x^8	float
# 	x^9	float
# 	x^10	float
# 	x^11	float
# 	x^12	float
# 	x^13	float
# 	x^14	float
# 	x^15	float
# 	x^16	float
# 	x^17	float
# 	x^18	float
# 	x^19	float
# 	x^20	float
# 	x^21	float
# 	x^22	float
# 	x^23	float
# 	x^24	float
# 	x^25	float
# 	x^26	float
# 	x^27	float
# 	x^28	float
# 	x^29	float
# 	x^30	float
# 	x^31	float
# 	x^32	float
# 	x^33	float
# 	x^34	float
# 	x^35	float
# 	x^36	float
# 	x^37	float
# 	x^38	float
# 	x^39	float
# 	x^40	float
# 	x^41	float
# 	x^42	float
# 	x^43	float
# 	x^44	float
# 	x^45	float
# 	x^46	float
# 	x^47	float
# 	x^48	float
# 	x^49	float
# 	x^50	float
# 	x^51	float
# 	x^52	float
# 	x^53	float
# 	x^54	float
# 	x^55	float
# 	x^56	float
# 	x^57	float
# 	x^58	float
# 	x^59	float
# 	x^60	float
# 	x^61	float
# 	x^62	float
# 	x^63	float
# 	x^64	float
# 	x^65	float
# 	x^66	float
# 	x^67	float
# 	x^68	float
# 	x^69	float
# 	x^70	float
# 	x^71	float
# 	x^72	float
# 	x^73	float
# 	x^74	float
# 	x^75	float
# 	x^76	float
# 	x^77	float
# 	x^78	float
# 	x^79	float
# 	x^80	float
# 	x^81	float
# 	x^82	float
# 	x^83	float
# 	x^84	float
# 	x^85	float
# 	x^86	float
# 	x^87	float
# 	x^88	float
# 	x^89	float
# 	x^90	float
# 	x^91	float
# 	x^92	float
# 	x^93	float
# 	x^94	float
# 	x^95	float
# 	x^96	float
# 	x^97	float
# 	x^98	float
# 	x^99	float
# 	x^100	float
# 	x^101	float
# 	x^102	float
# 	x^103	float
# 	x^104	float
# 	x^105	float
# 	x^106	float
# 	x^107	float
# 	x^108	float
# 	x^109	float
# 	x^110	float
# 	x^111	float
# 	x^112	float
# 	x^113	float
# 	x^114	float
# 	x^115	float
# 	x^116	float
# 	x^117	float
# 	x^118	float
# 	x^119	float
# 	x^120	float
# 	x^121	float
# 	x^122	float
# 	x^123	float
# 	x^124	float
# 	x^125	float
# 	x^126	float
# 	x^127	float
# 	x^128	float
# 	x^129	float
# 	x^130	float
# 	x^131	float
# 	x^132	float
# 	x^133	float
# 	x^134	float
# 	x^135	float
# 	x^136	float
# 	x^137	float
# 	x^138	float
# 	x^139	float
# 	x^140	float
# 	x^141	float
# 	x^142	float
# 	x^143	float
# 	x^144	float
# 	x^145	float
# 	x^146	float
# 	x^147	float
# 	x^148	float
# 	x^149	float
# 	x^150	float
# 	x^151	float
# 	x^152	float
# 	x^153	float
# 	x^154	float
# 	x^155	float
# 	x^156	float
# 	x^157	float
# 	x^158	float
# 	x^159	float
# 	x^160	float
# 	x^161	float
# 	x^162	float
# 	x^163	float
# 	x^164	float
# 	x^165	float
# 	x^166	float
# 	x^167	float
# 	x^168	float
# 	x^169	float
# 	x^170	float
# 	x^171	float
# 	x^172	float
# 	x^173	float
# 	x^174	float
# 	x^175	float
# 	x^176	float
# 	x^177	float
# 	x^178	float
# 	x^179	float
# 	x^180	float
# 	x^181	float
# 	x^182	float
# 	x^183	float
# 	x^184	float
# 	x^185	float
# 	x^186	float
# 	x^187	float
# 	x^188	float
# 	x^189	float
# 	x^190	float
# 	x^191	float
# 	x^192	float
# 	x^193	float
# 	x^194	float
# 	x^195	float
# 	x^196	float
# 	x^197	float
# 	x^198	float
# 	x^199	float
#
# Rows: 40
#
# Data:
# +---------------------+---------------------+--------------------+
# |          x          |          y          |        x^2         |
# +---------------------+---------------------+--------------------+
# | -0.8077508466412748 |  11.435560737659625 | 0.6524614302496963 |
# |  4.347062577364273  | -0.7707490836030138 | 18.896953051520917 |
# |  -2.957408005764636 |  2.9849247138055475 |  8.74626211256076  |
# |  -1.042141532087455 |  11.427949969110392 | 1.086058972901588  |
# |  1.7169022295997127 |  13.230349830673623 | 2.9477532660044647 |
# |  2.518644924144021  |  12.833429424592516 | 6.343572253916441  |
# |  -4.274568855068427 | -14.496518004055432 | 18.271938896721004 |
# |  4.960964478550945  |  -2.785716558377983 | 24.611168557444252 |
# | -4.2673927890036705 | -7.1177777541225105 | 18.210641215640525 |
# |   4.33259377993709  |  2.0894511298454015 | 18.77136886194956  |
# +---------------------+---------------------+--------------------+
# +---------------------+--------------------+---------------------+
# |         x^3         |        x^4         |         x^5         |
# +---------------------+--------------------+---------------------+
# | -0.5270262726849693 | 0.4257059179634793 | -0.3438643156552015 |
# |  82.14623743647618  | 357.09483463138565 |  1552.3135921961803 |
# |  -25.86626559220311 | 76.49710094161583  |  -226.2331387425201 |
# | -1.1318271619569886 | 1.179524092620052  | -1.2292310450171262 |
# |  5.061004154712901  | 8.689249317239987  |  14.918591526317117 |
# |  15.977206058267491 | 40.240908940658514 |  101.35256104633133 |
# |  -78.10466092963696 |  333.863751045506  | -1427.1235920554388 |
# |  122.09513298911084 | 605.7096177629326  |  3004.9038980385794 |
# |  -77.71195900675741 | 331.6274534847854  | -1415.1846036366235 |
# |  81.32871597218745  | 352.36428895136964 |  1526.6513265826595 |
# +---------------------+--------------------+---------------------+
# +--------------------+---------------------+---------------------+
# |        x^6         |         x^7         |         x^8         |
# +--------------------+---------------------+---------------------+
# | 0.2777566921002116 | -0.2243582032042258 | 0.18122552858912858 |
# |  6748.00432496992  |  29333.997072969003 |  127516.72092041669 |
# | 669.0636956863906  | -1978.6943299894056 |   5851.80645247176  |
# | 1.2810327245436113 | -1.3350174062100457 |  1.3912770850711573 |
# | 25.61376305402124  |  43.976326895887816 |  75.50305369715561  |
# | 255.27111342833942 |  642.9372941168797  |  1619.3307523703706 |
# | 6100.338058933558  | -26076.315072105972 |  111465.00426217559 |
# | 14907.221499628662 |  73954.19633354875  |  366884.1410505179  |
# | 6039.148572667945  | -25771.419070724995 |  109976.76790480352 |
# | 6614.3600416847385 |  28657.33517486773  |  124160.59212820431 |
# +--------------------+---------------------+---------------------+
# +----------------------+---------------------+----------------------+
# |         x^9          |         x^10        |         x^11         |
# +----------------------+---------------------+----------------------+
# | -0.14638507415088117 | 0.11824266758102005 | -0.09551061484769177 |
# |  554323.1655013473   |  2409677.488517009  |  10475018.833849417  |
# | -17306.179250725138  |  51181.43306529235  | -151364.37989380246  |
# | -1.4499076329942242  |  1.5110089620338962 | -1.5746851946918796  |
# |  129.63136123423328  |  222.5643731291009  |  382.1212684548157   |
# |  4078.5191799679524  |  10272.341630650319 |  25872.381107110738  |
# | -476464.83564916527  |  2036681.7470012186 |  -8705936.363417763  |
# |  1820099.191495294   |  9029447.436447449  |  44794767.99315868   |
# |  -469314.0663148888  |  2002747.462370147  |  -8546510.079113765  |
# |   537937.409167964   |  2330664.2729565944 |  10097821.53213334   |
# +----------------------+---------------------+----------------------+
# +---------------------+----------------------+---------------------+
# |         x^12        |         x^13         |         x^14        |
# +---------------------+----------------------+---------------------+
# | 0.07714878000645174 | -0.06231699236755285 | 0.05033660334502867 |
# |  45535562.36981275  |  197945939.1170498   |   860483384.276954  |
# |   447646.228885531  |  -1323872.541056418  |  3915231.2515322226 |
# |  1.6410448413516279 | -1.7102009851903999  |  1.7822714748837982 |
# |  656.0648577875435  |  1126.3992170974518  |  1933.917327253986  |
# |  65163.34135094413  |  164123.31893381962  |  413368.3641663351  |
# |  37214124.433273256 | -159074337.27111083  |   679974207.739741  |
# |  222225252.83899105 |  1102451585.571237   |  5469223155.341075  |
# |  36471315.48275727  |  -155637428.6965963  |   664166040.918928  |
# |  43749758.76103573  |  189549932.68181163  |  821242859.3247112  |
# +---------------------+----------------------+---------------------+
# +----------------------+----------------------+----------------------+
# |         x^15         |         x^16         |         x^17         |
# +----------------------+----------------------+----------------------+
# | -0.04065943396899294 | 0.032842692212409055 | -0.02652871244055222 |
# |  3740575118.2341084  |  16260514114.295433  |  70685472394.95724   |
# |  -11578936.24770129  |  34243638.75719013   | -101272411.40702625  |
# | -1.8573791254311696  |  1.9356519274440962  |  -2.017223265254626  |
# |  3320.346971023886   |  5700.711117595562   |  9787.563628103691   |
# |  1041128.1322092571  |  2622232.0855723904  |  6604471.532254491   |
# | -2906596570.6541257  |  12424447175.166822  | -53109154936.410995  |
# |  27132621798.915394  |  134603972954.37631  |   667765528498.493   |
# |  -2834257373.71855   |  12094889478.787022  |  -51613644145.5721   |
# |  3558111704.1279945  |  15415852637.626308  |  66790627250.206535  |
# +----------------------+----------------------+----------------------+
# +----------------------+----------------------+-----+
# |         x^18         |         x^19         | ... |
# +----------------------+----------------------+-----+
# | 0.021428589934158977 | -0.01730896166164561 | ... |
# |   307274171811.434   |  1335740053272.0847  | ... |
# |  299503840.25822926  |   -885755054.93694   | ... |
# |  2.102232144214914   | -2.1908234275756264  | ... |
# |  16804.28981544028   |  28851.322650969163  | ... |
# |  16634318.70136646   |  41895942.363790594  | ... |
# |  227018739610.18607  |  -970407233854.5903  | ... |
# |  3312761066881.8228  |  16434489978727.256  | ... |
# |  220255692841.0159   |  -939917555366.7585  | ... |
# |  289376656182.34155  |  1253751500634.607   | ... |
# +----------------------+----------------------+-----+
# [40 rows x 200 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# # Splitting data into training and testing

# %%
train, test = data.random_split(fraction=0.8, seed=0)

# %%
data.shape
# Out:
# (40, 200)

# %%
def display_results(model):
    coefs = model.coefficients
    print("Training error (rmse):", model.evaluate(train)['rmse'])
    print("Testing error (rmse):", model.evaluate(test)['rmse'])
    plt.scatter(train['x'], train['y'], marker='o')
    plt.scatter(test['x'], test['y'], marker='^')
    draw_polynomials(coefs['value'])
    plt.show()
    print("Polynomial coefficients")
    print(coefs['name', 'value'])

# %% [markdown]
# ##  $ \text{
# Training a polynomial regression model with various regularization} $

# %% [markdown]
# ## 1. with No regularization

# %%
model_no_reg = tc.linear_regression.create(
    train, target='y', l1_penalty=0.0, l2_penalty=0.0, verbose=False, validation_set=None)

# %%
display_results(model_no_reg)
# Out:
# Training error (rmse): 0.8626948629293241
# Testing error (rmse): 532.4541500829819
# Polynomial coefficients
# +-------------+----------------------+
# |     name    |        value         |
# +-------------+----------------------+
# | (intercept) |  19.049379226751626  |
# |      x      |  9.202107295484272   |
# |     x^2     | -10.270799050288474  |
# |     x^3     | -28.310166735305494  |
# |     x^4     |  4.116330205881551   |
# |     x^5     |  33.64067338478403   |
# |     x^6     | -0.1953633687051542  |
# |     x^7     | -17.225427421561346  |
# |     x^8     | -0.18458595194380437 |
# |     x^9     |  4.337475512601826   |
# +-------------+----------------------+
# [200 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# ## 2. with L1 regularization

# %%
model_L1_reg = tc.linear_regression.create(
    train, target='y', l1_penalty=0.1, l2_penalty=0.0, verbose=False, validation_set=None)

# %%
display_results(model_L1_reg)
# Out:
# Training error (rmse): 9.878844968377242
# Testing error (rmse): 5.697289068853273
# Polynomial coefficients
# +-------------+-------------------------+
# |     name    |          value          |
# +-------------+-------------------------+
# | (intercept) |    0.9376115215161254   |
# |      x      |    0.1437128037365557   |
# |     x^2     |  0.0021516107229312647  |
# |     x^3     |   0.006213181611070731  |
# |     x^4     |  -0.0006765512212943953 |
# |     x^5     |  0.00023134471319044748 |
# |     x^6     |  -3.983057043811317e-05 |
# |     x^7     |  7.588604630270607e-06  |
# |     x^8     | -1.7335650302495257e-06 |
# |     x^9     |  2.1855410247974002e-07 |
# +-------------+-------------------------+
# [200 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# ## 2. with L2 regularization

# %%
model_L2_reg = tc.linear_regression.create(
    train, target='y', l1_penalty=0.0, l2_penalty=0.1, verbose=False, validation_set=None)

# %%
display_results(model_L2_reg)
# Out:
# Training error (rmse): 1.7512402503149969
# Testing error (rmse): 2.31966588152
# Polynomial coefficients
# +-------------+-------------------------+
# |     name    |          value          |
# +-------------+-------------------------+
# | (intercept) |    15.030644988346657   |
# |      x      |    1.1751250115987235   |
# |     x^2     |   -0.7159526207007547   |
# |     x^3     |   0.013657221359186187  |
# |     x^4     |  -0.014907466330981283  |
# |     x^5     |  1.421275120724005e-05  |
# |     x^6     |  -0.0002445708860004861 |
# |     x^7     | -2.2716627251991542e-05 |
# |     x^8     | -1.4680385035981215e-06 |
# |     x^9     |  -7.025476805726451e-07 |
# +-------------+-------------------------+
# [200 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# ## Predictions

# %%
predictions = test['x', 'y']
predictions['No reg'] = model_no_reg.predict(test)
predictions['L1 reg'] = model_L1_reg.predict(test)
predictions['L2 reg'] = model_L2_reg.predict(test)

# %%
predictions
# Out:
# Columns:
# 	x	float
# 	y	float
# 	No reg	float
# 	L1 reg	float
# 	L2 reg	float
#
# Rows: 6
#
# Data:
# +---------------------+----------------------+--------------------+
# |          x          |          y           |       No reg       |
# +---------------------+----------------------+--------------------+
# |  3.3374495463980693 |  6.407206424321029   | 277.5167719377787  |
# | -2.0062124780002213 |  9.150035221519614   |  13.3064539959677  |
# |  2.7111922301962714 |  10.526836096069982  | 3.1150532943374856 |
# |  4.039285715598931  | -0.9160012299088081  | 1042.9443300652783 |
# |  3.9898148874259007 |  4.303858667159165   | 610.6346893531736  |
# |  4.298810156936744  | 0.022193818547056487 | 412.5636551254429  |
# +---------------------+----------------------+--------------------+
# +--------------------+--------------------+
# |       L1 reg       |       L2 reg       |
# +--------------------+--------------------+
# | 1.6327892445820513 |  9.16606495096165  |
# | 0.5850487348715138 | 9.426271819515158  |
# | 1.4516251262772135 | 12.293362630280036 |
# | 1.7641566291632045 | 3.609661925708778  |
# | 1.767314093135817  | 4.079620637143812  |
# | 1.642010107512845  | 0.9942874842758656 |
# +--------------------+--------------------+
# [6 rows x 5 columns]

# %%
model_no_reg.predict(test)
# Out:
# dtype: float
# Rows: 6
# [277.5167719377787, 13.3064539959677, 3.1150532943374856, 1042.9443300652783, 610.6346893531736, 412.5636551254429]
