# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib as mpl

plt.rcParams["figure.figsize"] = (15, 6)
plt.rcParams["figure.dpi"] = 150

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
f1 = sns.load_dataset("flights")
f1.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.set(style="darkgrid", color_codes=True)

f1 = sns.load_dataset("flights")
sns.relplot(x="passengers", y="month", data=f1)
plt.show()

# %%
sns.relplot(x="passengers", y="month", hue="year",palette='ch:r=1, l=0.9', data=f1)
plt.show()

# %%
sns.palplot(sns.color_palette("ch:2.5,-.2,dark=.3"));

# %%
presentcolors = sns.color_palette("ch:2.5,-.2,dark=.3")
sns.palplot(presentcolors)

# %%
gr=pd.DataFrame({'Day':[1,2,3,4,5,6,7],
                 'Grocery':[30,80,45,50,51,90,76],
                 'Clothes':[13,40,34,75,54,67,98],
                 'Utensils':[12,32,27,56,87,54,34]},
                index=[1,2,3,4,5,6,7])

# %%
gr.head()
# Out:
#    Day  Grocery  Clothes  Utensils
# 1    1       30       13        12
# 2    2       80       40        32
# 3    3       45       34        27
# 4    4       50       75        56
# 5    5       51       54        87

# %%
g = sns.relplot(x="Day", y="Clothes", kind="line", data=gr)
g.fig.autofmt_xdate()

# %% [markdown]
# Some plots :
# - lineplot
# - scatterplot
# - relplot
# - catplot
# - boxplot
# - violinplot
# - swarmplot
# - boxenplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks", color_codes=True)
tips = sns.load_dataset("tips")
sns.catplot(x="day", y="total_bill", data=tips);

# %%
sns.violinplot(x="day", y="total_bill", data=tips);

# %%
sns.displot(tips, x="total_bill", col="time", kde=True);

# %%
sns.displot(tips, x="total_bill", col="smoker", kde=True, rug=True);

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
sns.set(color_codes=True)
tst = np.random.normal(loc=10, size=500, scale=10)  #univariate data
sns.displot(tst, kde=True);

# %%
sns.histplot(tst, kde=True);

# %%
tst.mean()
# Out:
# 9.663190969154282

# %%
tst.std()
# Out:
# 10.312679588772886

# %%
tst.shape
# Out:
# (500,)

# %%
x=pd.DataFrame({
    'Day':[1,2,3,4,5,6,7],
    'Accessaries':[30,80,90,23,60,46,76],
    'Cloths':[13,40,60,23,54,67,98],
    'Shoes':[12,32,27,56,87,54,34]}, index=[1,2,3,4,5,6,7])

y=pd.DataFrame(
    {'Day':[8,9,10,11,12,13,14],
     'Accessaries':[30,90,45,23,60,46,76],
     'Cloths':[13,40,60,23,54,67,98],
     'Shoes':[12,32,27,56,87,54,34]},
  index=[8,9,10,11,12,13,14])

# %%
x.head()
# Out:
#    Day  Accessaries  Cloths  Shoes
# 1    1           30      13     12
# 2    2           80      40     32
# 3    3           90      60     27
# 4    4           23      23     56
# 5    5           60      54     87

# %%
y.head()
# Out:
#     Day  Accessaries  Cloths  Shoes
# 8     8           30      13     12
# 9     9           90      40     32
# 10   10           45      60     27
# 11   11           23      23     56
# 12   12           60      54     87

# %%
mean, cov = [0, 1], [(1, .5), (.5, 1)]

# %%
data = np.random.multivariate_normal(mean, cov, 200)

# %%
sns.jointplot(x=data[:, 0], y=data[:, 1], kind="kde", color='g');
